# %%
#Pkg.update()
#Pkg.add("MAT")

# %%
using Random, UnPack

# %%
using RegressionDynamicCausalModeling, Plots, MAT

# %%
dcm = load_example_DCM()
y, _, _, _ = generate_BOLD(dcm; SNR=10)
opt = Options(RigidInversionParams();synthetic=true,verbose=1)
# Out:
# Options{RigidInversionParams}(RigidInversionParams(500, 1.0e-5), 1, true, false, Random.MersenneTwister(0xfa621afc2031286a37d51beb8cf5bd3e))

# %%
rdcm = RigidRdcm(dcm)

# Invert the model (estimate posterior of parameters)
output = invert(rdcm, opt)

# Simulate BOLD signal based on estimated parameters
y_pred = predict(rdcm,output)

# %%
subject = "sub-1405"
nr = 242
scans = 240
timeseries_path = dirname(pwd())
timeseries_path = joinpath(timeseries_path, "SRPBS_OPEN/data", subject, "glm/VOI")
timeseries_cat = []
for file in readdir(timeseries_path, join=true)
    data = matread(file)
    @unpack Y = data
    timeseries_cat = [timeseries_cat; Y]
end
timeseries_reshape = reshape(timeseries_cat, (scans,nr))

# %%
#timeseries_reshape[:,1]
#timeseries_push[1,:]
#timeseries_reshape

# %%
plot(timeseries_reshape[:,1])

# %%
a = zeros(nr,nr)
for i in 1:nr
    for j in 1:nr
        if rand()<0.85
            a[i,j] = 1
        end
    end
end
Ep = rDCM.TrueParamLinear(a,zeros(nr,scans))
#Y = Dict(:y=>timeseries_reshape,"dt"=>2.5,"name"=>readdir(timeseries_path))
y = timeseries_reshape
dt = 2.5
name = readdir(timeseries_path)
dcm = LinearDCM(a,zeros(nr,scans),scans,nr,InputU(zeros(240,scans),2.5),BoldY(y,dt,name),Ep)
# Out:
# Linear DCM
# a:     242x242 matrix
# c:     242x240 matrix
# scans: 240
# nr:    242
# ---------------------------------------------
# U (Input)
#    u:  240x240 matrix
#    dt: 2.5s
#    names: u_1,...,u_240
# ---------------------------------------------
# Y (BOLD signal)
#    y:  240x242 matrix
#    dt: 2.5s
#    names: VOI_R001_SFG_7_1_left_1.mat,...,VOI_R246_Tha_8_8_right_1.mat
# ---------------------------------------------
# Ep (True parameters)
#     A: 242 x 242 matrix
#     C: 242 x 240 matrix
#     transit: 0.00 ... 0.00
#     decay:   0.00 ... 0.00
#     epsilon: 0.00

# %%
srdcm = SparseRdcm(dcm; p0=0.20)

# %%
opt = Options(
    SparseInversionParams(; reruns=100, restrictInputs=true);
    synthetic=true,
    rng=MersenneTwister(42),
)
output = invert(srdcm, opt)

# %%
rdcm = RigidRdcm(dcm)
# Out:
# rigid rDCM
# a:     242x242 matrix
# c:     242x241 matrix
# scans: 240
# nr:    242
# HRF:   240 element vector
# ---------------------------------------------
# U (Input)
#    u:  240x240 matrix
#    dt: 2.5s
#    names: u_1,...,u_240
# ---------------------------------------------
# Y (BOLD signal)
#    y:  240x242 matrix
#    dt: 2.5s
#    names: VOI_R001_SFG_7_1_left_1.mat,...,VOI_R246_Tha_8_8_right_1.mat
# ---------------------------------------------
# Ep (True parameters)
#     A: 242 x 242 matrix
#     C: 242 x 240 matrix
#     transit: 0.00 ... 0.00
#     decay:   0.00 ... 0.00
#     epsilon: 0.00
# ---------------------------------------------
# Confounds
#    X0:    240x1 matrix
#    names: Constant,...,Constant

# %%
opt = Options(RigidInversionParams(); verbose=2, synthetic=true, rng=MersenneTwister(42))
output = invert(rdcm, opt)
# Out:
# Running model inversion (rigid rDCM)
# Progress:   1%|█                                        |  ETA: 0:00:26
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:26
# rigid rDCM output
#     F:   -181492.80
#     F_r: -758.67 ... -705.82
#     iterations until convergence per region: 16 ... 21
#     Posteriors:
#         α: 122.50,...,122.50
#         β: 961.88,...,372.17
#         μ: 242 x 482 matrix
#         Σ: 242 element vector of matrices

# %%
y_pred = predict(rdcm, output)
plot(timeseries_reshape[:,1])
plot!(y_pred[:,1])

# %%
y_pred
# Out:
# 240×242 Matrix{Float64}:
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#    ⋮                        ⋮            ⋱    ⋮                        ⋮
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
